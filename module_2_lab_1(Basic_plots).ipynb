# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasvivek/FMML_projects_and_labs/blob/main/module_2_lab_1(Basic_plots).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This dataset consists of data from 1985 Ward's
# Automotive Yearbook for some features relating to nearly 200 cars (e.g. the car maker, mileage, dimensions, etc.) and their prices.
import requests
url = "https://raw.githubusercontent.com/SP9144/FMML_Data/main/Automobile_data.csv"
response = requests.get(url)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from io import StringIO
import matplotlib.pyplot as plt

# %%
# Loading the dataset
data = StringIO(response.text)
data = pd.read_csv(data)
print("Number of data points =", len(data))
data.head()
# Out:
# Number of data points = 205
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Removing rows which have missing values

data.replace("?", np.nan, inplace = True)
data = data.dropna()
print(len(data))
# Out:
# 159

# %%
# Dividing the dataset into features (X) and the target variable (y)

X = data.drop("price", axis = 1)
y = pd.to_numeric(data["price"])

# %%
plt.figure(figsize = (24, 7))
plt.scatter(X["make"], y)
plt.xlabel('Make')
plt.ylabel('Price')
plt.title('Car maker vs Price - Scatter Plot')
plt.show()

# %%
sns.set(rc={'figure.figsize':(24,7)})
sns.boxplot(x=X["make"],y=y, palette="Set3").set_title('Car Manufacturer vs Price - Box Plot')
# Out:
# <ipython-input-13-0447ba8df549>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["make"],y=y, palette="Set3").set_title('Car Manufacturer vs Price - Box Plot')
# Text(0.5, 1.0, 'Car Manufacturer vs Price - Box Plot')

# %%
sns.violinplot(x=X["make"],y=y, palette="Set3").set_title('Car maker vs Price - Violin Plot')
# Out:
# <ipython-input-14-10344be32235>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=X["make"],y=y, palette="Set3").set_title('Car maker vs Price - Violin Plot')
# Text(0.5, 1.0, 'Car maker vs Price - Violin Plot')

# %%
sns.swarmplot(x=X["make"],y=y).set_title('Car maker vs Price Swarm Plot')
# Out:
# Text(0.5, 1.0, 'Car maker vs Price Swarm Plot')

# %%
sns.boxplot(x=X["make"],y=pd.to_numeric(X["horsepower"]), palette="Set3").set_title('Car maker vs Horsepower Box Plot')
# Out:
# <ipython-input-16-c71fe76854fb>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["make"],y=pd.to_numeric(X["horsepower"]), palette="Set3").set_title('Car maker vs Horsepower Box Plot')
# Text(0.5, 1.0, 'Car maker vs Horsepower Box Plot')

# %%
sns.set(rc={'figure.figsize':(7,5)})
sns.scatterplot(x=pd.to_numeric(X["horsepower"]), y = y, color = "red")
# Out:
# <Axes: xlabel='horsepower', ylabel='price'>

# %%
sns.jointplot(x=pd.to_numeric(X["horsepower"]), y = y, kind="reg", color = 'blue')

# %%
############################
### CHANGE THE CODE HERE ###
# 'symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
# 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg
feature = "highway-mpg"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'purple')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "symboling"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'green')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "length"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'purple')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "wheel-base"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'purple')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "width"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'black')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "height"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'indigo')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "curb-weight"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
# 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg
############################
### CHANGE THE CODE HERE ###

feature = "engine-size"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'green')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "bore"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "stroke"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "compression-ratio"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "peak-rpm"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
############################
### CHANGE THE CODE HERE ###

feature = "city-mpg"

############################


sns.jointplot(x=pd.to_numeric(X[feature]), y = y, kind="reg", color = 'brown')

# %%
sns.boxplot(x=X["body-style"],y=y, palette="Set3").set_title('Body style vs Price Box Plot')
# Out:
# <ipython-input-39-5739ed01973b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=X["body-style"],y=y, palette="Set3").set_title('Body style vs Price Box Plot')
# Text(0.5, 1.0, 'Body style vs Price Box Plot')

# %% [markdown]
# 1ANS:
# "Convertible" body type has the highest maximum and median prices so is the costliest among the given bodytypes.
#
# 2Ans:
# No maximum/minimum values are a not clear indication of which body-type is costliest interpretation of the  interquartile range improves the indication.
#
# 3Ans: The box plots for different body styles show distinct price ranges. The convertible has the highest median and overall range, while sedan has the lowest. This suggests that body-style has an influence on price.While body-style can be a useful indicator of a car's price, it's not the sole determinant. It's one factor among many that contribute to the overall price.
#
# ```
# # This is formatted as code
# ```

# %%
# excersise 2 ans:
import seaborn as sns
import pandas as pd

# Assuming your data is in DataFrames named X and y

# Create the joint plot using regplot or lmplot instead of catplot for regression
sns.catplot(x=pd.to_numeric(X["horsepower"]), y=y, color="blue")
# OR
# sns.lmplot(x="horsepower", y="price", data=data,  line_kws={'color': 'blue'})

# Show the plot
plt.show()
